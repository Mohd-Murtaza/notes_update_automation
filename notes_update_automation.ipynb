# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time

# ==== CONFIGURATION ====
LMS_BASE_URL = "https://experience-admin.masaischool.com/"
# LOGIN_URL    = f"{LMS_BASE_URL}/login"
USERNAME     = "it should be your LSM Email"
PASSWORD     = "it should be your password"

# ==== START SELENIUM ====
driver = webdriver.Chrome()
driver.maximize_window()

driver.get(LMS_BASE_URL)

#Login 
time.sleep(2)
driver.find_element(By.ID, "email1").send_keys(USERNAME)
time.sleep(2)
driver.find_element(By.ID, "password1").send_keys(PASSWORD)
time.sleep(2)
driver.find_element(By.XPATH, "//*[@id='__next']/div/div/div/form/button").click()
time.sleep(2)


# update the lecture here 

lecture_list =  [
  "PTTEU04-MU03: Functions & Reusability",
  "PTTEU04-MU03: Arrays & Objects",
  "PTTEU04-MU03: Higher Order Functions"
]

# %%
for item in lecture_list:
    driver.get("https://experience-admin.masaischool.com/lectures/?page=0")
    code_str, title = item.split(": ", 1)
    batch_name="PSD"
    if code_str.startswith("F"):
        batch_name = "FSD"
    section_name=code_str.strip().split("_")[0]
    print(section_name, "this is section_name")
    unit = section_name[-1]
    remain_section= section_name[:-1]
    prev_unit=int(unit)-1
    prev_section = remain_section + str(prev_unit)  
    # prev_section="FSDU41-MU01"
    print(batch_name,section_name, prev_section, "this is batch_name and section_name, and prev_section")
    time.sleep(2)
    driver.find_element(By.ID, "search").send_keys(title)
    time.sleep(2)
    driver.find_element(By.XPATH,"/html/body/div/div/div/main/div[2]/div/div/button").click()
    time.sleep(1)
    type_box = driver.find_element(By.XPATH,"/html/body/div/div/div/main/div[2]/div[2]/div[1]/label[3]/div/div/div[1]/div[2]/input")
    type_box.clear()
    time.sleep(2)
    type_box.send_keys("live")
    time.sleep(2)
    driver.find_element(By.XPATH, "/html/body/div/div/div/main/div[2]/div[2]/div[1]/label[3]/div/div[2]/div/div[1]").click()
    time.sleep(2)
    batch_box = driver.find_element(By.XPATH,"/html/body/div/div/div/main/div[2]/div[2]/div[1]/label[4]/div/div/div[1]/div[2]/input")
    batch_box.clear()
    time.sleep(2)
    batch_box.send_keys(batch_name)
    time.sleep(2)
    driver.find_element(By.XPATH, "/html/body/div/div/div/main/div[2]/div[2]/div[1]/label[4]/div/div[2]/div/div").click()
    time.sleep(2)
    section_box=driver.find_element(By.XPATH, "/html/body/div/div/div/main/div[2]/div[2]/div[1]/label[5]/div/div/div[1]/div[2]/input")
    section_box.clear()
    time.sleep(2)
    section_box.send_keys(prev_section)
    time.sleep(2)
    driver.find_element(By.XPATH, "/html/body/div/div/div/main/div[2]/div[2]/div[1]/label[5]/div/div[2]/div/div").click()
    time.sleep(2)
    driver.find_element(By.XPATH,"/html/body/div/div/div/main/div[3]/div/div[2]/table/tbody/tr/td[2]/a/p").click()
    url = driver.current_url
    # print("Previous url",url)
    url = url.replace("detail","edit")
    driver.get(url)
    time.sleep(3)
    
    notes = driver.find_element(By.XPATH,"/html/body/div/div/div/main/form/div[5]/div/div[2]/div[1]/div/textarea")
    notes.click()
    time.sleep(2)
    actions = ActionChains(driver)
    actions.key_down(Keys.COMMAND).send_keys('a').send_keys('c').key_up(Keys.COMMAND).perform()

    driver.get("https://experience-admin.masaischool.com/lectures/?page=0")
    time.sleep(2)
    driver.find_element(By.ID, "search").send_keys(item) # Change with the loop variable
    time.sleep(2)
    driver.find_element(By.XPATH,"/html/body/div/div/div/main/div[3]/div/div[2]/table/tbody/tr/td[2]/a/p").click()
    url = driver.current_url
    # print("Previous url",url)
    url = url.replace("detail","edit")
    driver.get(url)
    time.sleep(2)
    driver.find_element(By.XPATH,"/html/body/div/div/div/main/form/div[1]/div[3]/div/div/label[1]/div/div/div[2]").click()
    driver.find_element(By.XPATH,"/html/body/div/div/div/main/form/div[1]/div[3]/div/div/label[1]/div/div[2]/div/div[1]").click()


    driver.find_element(By.XPATH,"/html/body/div/div/div/main/form/div[1]/div[3]/div/div/label[2]/div/div/div[2]").click()
    time.sleep(2)
    driver.find_element(By.XPATH,"/html/body/div/div/div/main/form/div[1]/div[3]/div/div/label[2]/div/div[2]/div/div[1]").click()


    driver.find_element(By.XPATH,"/html/body/div/div/div/main/form/div[1]/div[3]/div/div/label[3]/div/div/div[2]").click()
    try:
        driver.find_element(By.XPATH,"/html/body/div/div/div/main/form/div[1]/div[3]/div/div/label[3]/div/div[2]/div/div[1]").click()
    except:
        print("Learning objective already added")
    time.sleep(2)
    # print(notes)
    destination = driver.find_element(By.XPATH, "/html/body/div/div/div/main/form/div[5]/div/div[2]/div[1]/div/textarea")
    # destination.clear()
    time.sleep(2)
    destination.click()
    time.sleep(2)
    actions = ActionChains(driver)
    actions.key_down(Keys.COMMAND).send_keys('a').key_up(Keys.COMMAND).send_keys(Keys.BACKSPACE).key_down(Keys.COMMAND).send_keys('v').key_up(Keys.COMMAND).send_keys(Keys.ENTER).perform()
    time.sleep(2)

    driver.find_element(By.XPATH,"/html/body/div/div/div/main/form/div[6]/button").click()
    print("Notes updated for: ",item)
    # cur_code  = code_str
# Out:
# PTTEU04-MU03 this is section_name
# PSD PTTEU04-MU03 PTTEU04-MU02 this is batch_name and section_name, and prev_section
# Notes updated for:  PTTEU04-MU03: Functions & Reusability
# PTTEU04-MU03 this is section_name
# PSD PTTEU04-MU03 PTTEU04-MU02 this is batch_name and section_name, and prev_section
# Notes updated for:  PTTEU04-MU03: Arrays & Objects
# PTTEU04-MU03 this is section_name
# PSD PTTEU04-MU03 PTTEU04-MU02 this is batch_name and section_name, and prev_section
# Notes updated for:  PTTEU04-MU03: Higher Order Functions
